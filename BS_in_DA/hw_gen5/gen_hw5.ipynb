# %% [markdown]
# # Генеративные нейросети
# ## Задание 5
#
# **Правила:**
#
# * Дедлайны см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Выполненную работу нужно отправить телеграм-боту. Для начала работы с ботом каждый раз отправляйте `/start`. Дождитесь подтверждения от бота, что он принял файл. Если подтверждения нет, то что-то не так. **Работы, присланные иным способом, не принимаются.**
# * Дедлайны см. в боте. После дедлайна работы не принимаются кроме случаев наличия уважительной причины.
# * Прислать нужно **ноутбук в формате `ipynb`**.
# * Следите за размером файлов. **Бот не может принимать файлы весом более 20 Мб.** Если файл получается больше, заранее разделите его на несколько.
# * Выполнять задание необходимо полностью самостоятельно. **При обнаружении списывания все участники списывания получат штраф.**
# * Решения, размещенные на каких-либо интернет-ресурсах, не принимаются. Кроме того, публикация решения в открытом доступе может быть приравнена к предоставлении возможности списать.
# * Для выполнения задания используйте этот ноутбук в качестве основы, **не исправляйте и не удаляйте условия!** Можно добавлять необходимое количество ячеек.
# * Комментарии к решению пишите в markdown-ячейках.
# * Выполнение задания (ход решения, выводы и пр.) должно быть осуществлено на русском языке.
# * Решение проверяется системой ИИ-проверки <a href="https://thetahat.ru/"><img src="https://miptstats.github.io/theta_grader_small.png" style="display: inline; vertical-align: middle;"></a> **ThetaGrader**. Результат проверки валидируется и исправляется человеком, после чего комментарии отправляются студентам.
# * Если код будет не понятен проверяющему, оценка может быть снижена.
# * Никакой код из данного задания при проверке запускаться не будет. *Если код студента не выполнен, недописан и т.д., то он не оценивается.*
# * В каждой задаче не забывайте делать **пояснения и выводы**.
# * **Код из рассказанных на занятиях ноутбуков** можно использовать без ограничений.
#
#
# **Правила оформления теоретических задач:**
#
# * Решения необходимо прислать в виде $LaTeX$ в markdown-ячейках.
# * В решениях поясняйте, чем вы пользуетесь, хотя бы кратко. Например, если пользуетесь независимостью, то достаточно подписи вида "*X и Y незав.*"
# * Решение, в котором есть только ответ, и отсутствуют вычисления, оценивается в 0 баллов.
#
#
#
#
#
# **Баллы за задание:**
# * Задача 0 — 5 баллов.
# * Задача 1 — 40 баллов.
# * Задача 2 — 20 баллов.
# * Задача 3 — 90 баллов.
# * Задача 4 — 60 баллов.
#
# -----------

# %%
# Bot check

# HW_ID: ds_gen5
# Бот проверит этот ID и предупредит, если случайно сдать что-то не то.

# Status: not final
# Перед отправкой в финальном решении удали "not" в строчке выше.
# Так бот проверит, что ты отправляешь финальную версию, а не промежуточную.
# Никакие значения в этой ячейке не влияют на факт сдачи работы.

# %% [markdown]
# ### Ссылки на использование ИИ
#
# Если при решении задач использовался ИИ, укажи здесь публичные ссылки на все чаты с ИИ и поясни, для каких целей он применялся. Обрати внимание на <a href="https://thetahat.ru/courses/ai-rules" target="_top">правила</a>.
#
# **Задача 1**
# 1. ссылка
#     - для чего использована
#     - для чего использована
# 2. ссылка
#     - для чего использована
#
# **Задача 2**
# 1. ссылка
#     - для чего использована
# ...

# %% [markdown]
# ---
# ### Задача 0.
#
# Оцените сгенерированные картинки из прошлого задания :)
#
# https://t.me/compare_ds_images_bot

# %% [markdown]
# ---
# ### Задача 1.
#
# Докажите, что для вариационного распределения в диффузионной модели справедливо
# $$X_{t-1} | X_t, X_0\ \stackrel{\mathsf{Q}}{\sim}\ \mathcal{N}\left(\widetilde{\mu}(X_t, X_0),\ \widetilde{\beta}_t I_d\right),$$
# где
# $$\widetilde{\mu}(x_t, x_0) = \frac{\sqrt{\widetilde{\alpha}_{t-1}}\beta_t}{1 - \widetilde{\alpha}_t}x_0 + \frac{\sqrt{1 - \beta_t}(1 - \widetilde{\alpha}_{t -1})}{1 - \widetilde{\alpha}_t}x_t,$$
# $$\widetilde{\beta}_t = \frac{1 - \widetilde{\alpha}_{t -1}}{1 - \widetilde{\alpha}_t},$$
# $$\widetilde{\alpha}_t = \prod\limits_{s=1}^t\alpha_s,\ \ \alpha_t = 1 - \beta_t.$$

# %% [markdown]
# $\square$
#
# ## ВЫПОЛНЕН В ПДФ
#
# $\blacksquare$

# %% [markdown]
# ---
# ### Задача 2.
#
# Напомним, мы задали априорное распределение латентных величин как $X_{t-1}|X_t \ \stackrel{\mathsf{P_\theta}}{\sim}\  \mathcal{N}\left(\mu_\theta(X_t, t), \widetilde{\beta}_t\right)$. Покажите, что
# $$\mu_\theta(x_t, t) = \frac{1}{\sqrt{\alpha_t}}\left(x_t - \frac{1-\alpha_t}{\sqrt{1 - \widetilde{\alpha}_t}}\delta_\theta(x_t, t)\right).$$
# Эта формула используется для итераций семплирования новых объектов.

# %% [markdown]
# $\square$
# ## ВЫПОЛНЕН В PDF
# $\blacksquare$

# %% [markdown]
# ---
# ### Задача 3.
#
# В этой задаче мы на простых примерах разберем основные формулы стохастических дифференциальных уравнений для диффузионных моделей. На практике обычно целевое распределение неизвестно, есть только выборка из него. Но цель этой задачи — понять принцип работы формул. Поэтому мы рассмотрим их в случае, когда все распределения известны.

# %% [markdown]
# **1.** Рассмотрим в качестве целевого распределения $\mathsf{P}_0$ многомерное нормальное $\mathcal{N}(a, \Sigma)$. Найдите распределение зашумленного объекта на шаге $t$, используя явную формулу, а также производную его плотности по аргументу.

# %% [markdown]
# Мы уже вывели нужные формулы в прошлых номерах, просто применим их.
#
# $X_t = \sqrt{\tilde{\alpha}_t} X_0 + \sqrt{(1 - \tilde{\alpha}_t)}\varepsilon_t \sim N(\sqrt{\tilde{\alpha}_t}a,\tilde{\alpha}_t\Sigma + (1 - \tilde{\alpha}_t)I_d)$

# %% [markdown]
# Обозначим дисперсию за A.
#
# Тогда имеем следующую плотность
#
# $$
# p_t(x) = (2\pi \det A)^{-d/2}\exp\left(-\frac{1}{2}(x - \sqrt{\tilde{\alpha}_t}a)^T A^{-1}(x - \sqrt{\tilde{\alpha}_t}a)\right)
# $$

# %% [markdown]
# Продифференцируем, получим:
#
# $$
# \nabla_{x}p_{t}(x) = -p_{t}(x)A^{-1}(x - \sqrt{\tilde{\alpha_t}}a)
# $$
#
# Заодно получим сразу градиент логарифма, он понадобится нам далее:
# $$
# \nabla_{x}\log(p_{t}(x)) = -A^{-1}(x - \sqrt{\tilde{\alpha_t}}a)
# $$

# %% [markdown]
# Выпишите дифференциальные уравнения:
# * прямое стохастическое,
# * обратное стохастическое,
# * обратное обыкновенное.
#
# Укажите также начальное распределение.

# %% [markdown]
# Прямое стохастическое:
#
# $$
# dX_t = -\frac{1}{2}\beta_t X_t dt + \sqrt{\beta_t}dW_t,
# $$
# где $W_t$ -- итерация винеровского процесса.

# %% [markdown]
# Обратное стохастическое:
# $$
# dX_t = \left(-\frac{1}{2}\beta_t X_t +\beta_t A^{-1}(X_t - \sqrt{\tilde{\alpha_t}}a) \right)dt + \sqrt{\beta_t}dW_t
# $$

# %% [markdown]
# Обратное обыкновенное:
# $$
# dX_t = \left(-\frac{1}{2}\beta_t X_t + \frac{1}{2}\beta_t A^{-1}(X_t - \sqrt{\tilde{\alpha_t}}a)\right)dt
# $$

# %% [markdown]
# Начальное распределение:
# $$
# X_0 \sim N(a, \Sigma)
# $$
# $$
# X_T \sim N(0, I_d)
# $$

# %% [markdown]
# **2.** Реализуйте итерации по этим уравнениям в двумерном случае, изменяя $t$ на отрезке $[0, 1]$ за 1000 шагов. Визуализируйте траектории нескольких точек для каждого из уравнений.
#
# Примеры визуализации можно посмотреть с занятия, анимацию делать не обязательно.

# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.array([2.0, 2.0])
Sigma = np.array([[2.0, 0.5], [0.5, 1.0]])
Sigma_inv = np.linalg.inv(Sigma)

P_0 = sps.multivariate_normal(mean=a, cov=Sigma)

# %%
T = 1000
t_s = np.arange(0, T)
beta_t = np.linspace(1e-2, 1e-4, T)
alpha_t = 1 - beta_t
alpha_hat_t = np.cumprod(alpha_t)

# %%
n_dots = 100
d = 2

means_t = np.sqrt(alpha_hat_t)[:, None] * a
covs_t = (
    alpha_hat_t[:, None, None] * Sigma[None]
    + (1 - alpha_hat_t)[:, None, None] * np.eye(d)
)

X_t = np.zeros((t_s.shape[0], n_dots, d))

for i in range(t_s.shape[0]):
    X_t[i] = sps.multivariate_normal(
        mean=means_t[i],
        cov=covs_t[i],
    ).rvs(size=n_dots)

# %%
x = np.linspace(-4, 5, 500)
y = np.linspace(-3, 5, 500)
Xg, Yg = np.meshgrid(x, y)
pos = np.dstack((Xg, Yg))

Z_p0 = P_0.pdf(pos)
Z_std = sps.multivariate_normal(mean=[0, 0], cov=np.eye(2)).pdf(pos)

sns.set_style("whitegrid")
sns.set_palette("husl")

plt.figure(figsize=(12, 8))

contour_std = plt.contourf(Xg, Yg, Z_std, levels=50, cmap='Reds', alpha=0.5)

contour_p0 = plt.contourf(Xg, Yg, Z_p0, levels=50, cmap='Blues', alpha=0.5)

cbar1 = plt.colorbar(contour_p0, label='Density of $P_0$')
cbar1.ax.tick_params(labelsize=10)
cbar2 = plt.colorbar(contour_std, label='Density of Standard Normal')
cbar2.ax.tick_params(labelsize=10)

plt.scatter(X_t[0, :, 0], X_t[0, :, 1], 
            label="Initial samples $X_t[0]$", 
            c='blue', edgecolor='black', s=50, alpha=0.7)
plt.scatter(X_t[-1, :, 0], X_t[-1, :, 1], 
            label="Final samples $X_t[T-1]$", 
            c='orange', edgecolor='black', s=50, alpha=0.7)

plt.xlim(-3, 3)
plt.ylim(-2, 4)
plt.axis('equal')

plt.title("Distribution $P_0$ and Standard Normal with Samples", fontsize=14, fontweight='bold')
plt.xlabel("$x_1$", fontsize=12)
plt.ylabel("$x_2$", fontsize=12)
plt.legend(loc='upper right', fontsize=10, framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# Сравните распределения вектора $X_t$ для двух видов обратных уравнений &mdash; стохастического и обыкновенного. Проведите сравнение для нескольких различных $t$.

# %%
t_to_show = [int(i) for i in np.linspace(0, T-1, 10)]

# %% [markdown]
# Начнем с обратного стохастического

# %%
X_restored_stochastic = np.zeros_like(X_t)
X_restored_stochastic[-1] = X_t[-1]

std_norm = sps.multivariate_normal(mean=[0, 0], cov=np.eye(2))
dt = 1.0

for i in range(T-1, 0, -1):
    A = np.sqrt(alpha_hat_t[i]) * Sigma + (1 - alpha_hat_t[i]) * np.eye(2)
    A_inv = np.linalg.inv(A)
    
    diff = X_restored_stochastic[i] - a * np.sqrt(alpha_hat_t[i])
    drift = -0.5 * beta_t[i] * X_restored_stochastic[i] + (beta_t[i] * (A_inv @ diff.T).T)
    
    epsilon = std_norm.rvs(size=X_restored_stochastic[i].shape[0])
    diffusion = np.sqrt(beta_t[i] * dt) * epsilon
    
    X_restored_stochastic[i-1] = X_restored_stochastic[i] - drift * dt - diffusion

# %% [markdown]
# Теперь обратное обыкновенное

# %%
X_restored_ordinary = np.zeros_like(X_t)
X_restored_ordinary[-1] = X_t[-1]

dt = 1.0

for i in range(T - 1, 0, -1):
    A = np.sqrt(alpha_hat_t[i]) * Sigma + (1 - alpha_hat_t[i]) * np.eye(2)
    A_inv = np.linalg.inv(A)

    diff = X_restored_ordinary[i] - a * np.sqrt(alpha_hat_t[i])
    drift = -0.5 * beta_t[i] * X_restored_ordinary[i] + 0.5 * (
        beta_t[i] * (A_inv @ diff.T).T
    )

    X_restored_ordinary[i - 1] = X_restored_ordinary[i] - drift * dt

# %%
fig, axes = plt.subplots(2, 5, figsize=(25, 12))
axes = axes.flatten()

for idx, t_idx in enumerate(sorted(t_to_show, reverse=True)):
    ax = axes[idx]

    ax.scatter(
        X_restored_stochastic[t_idx, :, 0],
        X_restored_stochastic[t_idx, :, 1],
        c="orange",
        edgecolor="black",
        s=30,
        alpha=0.7,
        label="Restored stochaticly samples",
        marker="*",
    )

    ax.scatter(
        X_restored_ordinary[t_idx, :, 0],
        X_restored_ordinary[t_idx, :, 1],
        c="green",
        edgecolor="black",
        s=30,
        alpha=0.7,
        label="Restored ordinary samples",
        marker="x",
    )

    ax.contourf(Xg, Yg, Z_p0, levels=50, cmap="Blues", alpha=0.4)

    ax.set_title(f"$t = {t_idx}$", fontsize=14)
    ax.set_xlim(Xg.min(), Xg.max())
    ax.set_ylim(Yg.min(), Yg.max())
    ax.set_aspect("equal")
    ax.grid(True, alpha=0.3)

axes[-1].legend(loc="upper right", fontsize=12, framealpha=0.9)

plt.tight_layout()
plt.show()
# Out:
# /home/udeneev-av/tmp/ipykernel_700847/600374286.py:18: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %% [markdown]
# Тут синим цветом выделено истинное распределение, как видим именно в него точки и переходят.

# %% [markdown]
# **3.** Делать перевод распределений из нормального в нормальное не так интересно, рассмотрим более сложный пример :)
#
# Рассмотрим в качестве целевого распределения $\mathsf{P}_0$ равномерное на единичном кубе $[0, 1]^d$. Выпишите дифференциальные уравнения аналогично пункту 1.
#
# *Указания.*
# 1. В данном случае на протяжении всего процесса координаты $X_t$ независимы, поэтому задачу достаточно решить
# для случая $d=1$.
# 2. Для нахожения распределения $X_t$ воспользуйтесь формулой свертки, связывающей распределение $X_0$ и условное $X_t|X_0$, ей мы воспользовались на лекции при оценке скор-функции. Сведите эту плотность к разности значений функции распределения стандартного нормального в двух точках. Продифференцировать ее вы легко сможете.

# %% [markdown]
# Начальное распределение:
# $$
# X_0 \sim U([0, 1]^d)
# $$
# $$
# X_T \sim N(0, I_d)
# $$

# %% [markdown]
# Как и сказано в указании, так как координаты $X_t$ независимы, то мы можем ограничиться случаем d=1.
#
# В №1 мы получили
# $$
# X_t|X_0 \sim N(\sqrt{\tilde{\alpha_t}}X_0, (1 - \tilde{\alpha}_t) I_d)
# $$
#
# \begin{align*}
# p_t(x) &= \int_{0}^{1} p_0(x_0) \cdot q_t(x|x_0)dx_0 = \int_{0}^{1} N\left(x|\sqrt{\tilde{\alpha_t}}x_0, (1 - \tilde{\alpha}_t)\right) dx_0 \\
# &= \int_{0}^{1}(2\pi (1 - \tilde{\alpha}_t))^{-1/2} \exp\left(-\frac{1}{2(1 - \tilde{\alpha}_t)}\left(x - \sqrt{\tilde{\alpha_t}}x_0\right)^2 \right)dx_0 \\
# &=\left[a = \sqrt{\tilde{\alpha}_t}, \sigma = \sqrt{1 - \tilde{\alpha}_t}, y=ax_0, dx_0 =\frac{dy}{a} \right] \\
# &= \frac{1}{a}\int_{0}^{a} \frac{1}{\sqrt{2\pi}\sigma}\exp\left(-\frac{1}{2\sigma^2}(x-y)^2 \right)dy \\
# &= \left[z = \frac{x-y}{\sigma} \right] = \frac{1}{a}\int_{(x-a)/\sigma}^{x/\sigma}N(z|0, 1)dz =\frac{1}{a}\left(\Phi\left(\frac{x}{\sigma}\right) - \Phi\left(\frac{x-a}{\sigma}\right) \right)
# \end{align*}
#
# А как мы помним, производная функции распределения по аргументу явялется плотностью, тогда:
# $$
# \frac{\partial p_t(x)}{\partial x} = \frac{1}{a\sigma}\left(\phi\left(\frac{x}{\sigma}\right) - \phi\left(\frac{x-a}{\sigma}\right) \right)
# $$
#
# И сразу получаем производную логарифма:
# \begin{align*}
# \frac{\partial \log p_t(x)}{\partial x} = \frac{p_t'(x)}{p_t(x)} = \frac{1}{\sigma}\frac{\phi\big(\tfrac{x}{\sigma}\big)-\phi\big(\tfrac{x-a}{\sigma}\big)}
# {\Phi\big(\tfrac{x}{\sigma}\big)-\Phi\big(\tfrac{x-a}{\sigma}\big)}
# \end{align*}

# %% [markdown]
# Теперь выпишем дифференциальные уравнения, в них изменится только часть с производной логарифма.
#
# Обратное стохастическое:
# $$
# dX_t = \left(-\frac{1}{2}\beta_t X_t - \beta_t \frac{1}{\sigma}\frac{\phi\big(\tfrac{x}{\sigma}\big)-\phi\big(\tfrac{x-a}{\sigma}\big)}
# {\Phi\big(\tfrac{x}{\sigma}\big)-\Phi\big(\tfrac{x-a}{\sigma}\big)} \right)dt + \sqrt{\beta_t}dW_t
# $$

# %% [markdown]
# Обратное обыкновенное:
# $$
# dX_t = \left(-\frac{1}{2}\beta_t X_t - \frac{1}{2}\beta_t \frac{1}{\sigma}\frac{\phi\big(\tfrac{x}{\sigma}\big)-\phi\big(\tfrac{x-a}{\sigma}\big)}
# {\Phi\big(\tfrac{x}{\sigma}\big)-\Phi\big(\tfrac{x-a}{\sigma}\big)} \right)dt
# $$

# %% [markdown]
# Прямое стохастическое то же, начальное распределения указаны в начале.

# %% [markdown]
# **4.** Повторите исследование из пункта 2 для дифференциальных уравнений из пункта 3.

# %% [markdown]
# Я возьму d=2 для лучшей визуализации.

# %%
P_0 = sps.uniform(loc=0, scale=1)
T = 1000
t_s = np.arange(0, T)
beta_t = np.linspace(1e-2, 1e-4, T)
alpha_t = 1 - beta_t
alpha_hat_t = np.cumprod(alpha_t)
n_dots = 100
d = 2

X_0 = np.random.uniform(0, 1, size=(n_dots, d))

for i in range(t_s.shape[0]):
    mean = np.sqrt(alpha_hat_t[i]) * X_0
    cov  = (1 - alpha_hat_t[i]) * np.eye(d)
    X_t[i] = mean + np.random.randn(n_dots, d) * np.sqrt(1 - alpha_hat_t[i])

# %%
def score_func(X_t, alpha_hat, t):
    a = np.sqrt(alpha_hat[t])
    sigma = np.sqrt(1 - alpha_hat[t]) + 1e-9
    u1 = X_t / sigma
    u2 = (X_t - a) / sigma
    numerator = sps.norm.pdf(u1) - sps.norm.pdf(u2)
    denominator = sps.norm.cdf(u1) - sps.norm.cdf(u2) + 1e-9
    score = (1 / sigma) * numerator / denominator
    return score

# %% [markdown]
# Снова начнем со стохастического

# %%
X_restored_stochastic = np.zeros_like(X_t)
X_restored_stochastic[-1] = X_t[-1]

std_norm = sps.multivariate_normal(mean=[0, 0], cov=np.eye(2))
dt = 1.0

for i in range(T-1, 0, -1):
    drift = -0.5 * beta_t[i] * X_restored_stochastic[i] - beta_t[i] * score_func(X_restored_stochastic[i], alpha_hat_t, i)
    
    epsilon = std_norm.rvs(size=X_restored_stochastic[i].shape[0])
    diffusion = np.sqrt(beta_t[i] * dt) * epsilon
    
    X_restored_stochastic[i-1] = X_restored_stochastic[i] - drift * dt - diffusion

# %% [markdown]
# Теперь обыкновенное

# %%
X_restored_ordinary = np.zeros_like(X_t)
X_restored_ordinary[-1] = X_t[-1]

dt = 1.0

for i in range(T - 1, 0, -1):
    drift = -0.5 * beta_t[i] * X_restored_ordinary[i] - 0.5 * beta_t[i] * score_func(X_restored_ordinary[i], alpha_hat_t, i)
    
    X_restored_ordinary[i - 1] = X_restored_ordinary[i] - drift * dt

# %%
x = np.linspace(-3, 3, 500)
y = np.linspace(-3, 3, 500)
Xg, Yg = np.meshgrid(x, y)
pos = np.dstack((Xg, Yg))

Z_p0 = (
    (Xg >= 0) & (Xg <= 1) &
    (Yg >= 0) & (Yg <= 1)
).astype(float)

# стандартная нормаль 2D
Z_std = sps.multivariate_normal(mean=[0, 0], cov=np.eye(2)).pdf(pos)


fig, axes = plt.subplots(2, 5, figsize=(25, 12))
axes = axes.flatten()

for idx, t_idx in enumerate(sorted(t_to_show, reverse=True)):
    ax = axes[idx]

    ax.scatter(
        X_restored_stochastic[t_idx, :, 0],
        X_restored_stochastic[t_idx, :, 1],
        c="orange",
        edgecolor="black",
        s=30,
        alpha=0.7,
        label="Restored stochaticly samples",
        marker="*",
    )

    ax.scatter(
        X_restored_ordinary[t_idx, :, 0],
        X_restored_ordinary[t_idx, :, 1],
        c="green",
        s=30,
        alpha=0.7,
        label="Restored ordinary samples",
        marker="x",
    )

    ax.contourf(Xg, Yg, Z_p0, levels=50, cmap="Blues", alpha=0.4)

    ax.set_title(f"$t = {t_idx}$", fontsize=14)
    ax.set_xlim(Xg.min(), Xg.max())
    ax.set_ylim(Yg.min(), Yg.max())
    ax.set_aspect("equal")
    ax.grid(True, alpha=0.3)

axes[-1].legend(loc="upper right", fontsize=12, framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# **5.** Сделайте выводы.

# %% [markdown]
# **Выводы:**
#
# Мы собственноручно убедились в правильности формул обратных дифференциальных уравнений полученных на семинаре. Отмети, что восстановление сильнее всего заметно на последних шагах, до этого данные сложно отличить от стандартного нормального, это справедливо как для изначально нормального распределения, так и для равномерного на d-мерном кубе.

# %%
import os
os.environ["OMP_NUM_THREADS"] = "20"
os.environ["MKL_NUM_THREADS"] = "20"
os.environ["NUMEXPR_NUM_THREADS"] = "20"
os.environ["OPENBLAS_NUM_THREADS"] = "20"
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
from torchsummary import summary
from torchmetrics.image.fid import FrechetInceptionDistance
from torchvision.models import inception_v3

from sklearn.datasets import make_blobs
from matplotlib.gridspec import GridSpec
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from torch.utils.data import TensorDataset, DataLoader
import math
from umap import UMAP

from torch.autograd import Variable
from torchvision.datasets import ImageFolder
from torch.amp import autocast, GradScaler
from torch.utils.data import DataLoader, random_split, Dataset
from torchvision import datasets, transforms
from torchvision.utils import make_grid
from datetime import datetime
from IPython.display import clear_output
from tqdm.auto import tqdm
import torch.nn.functional as F
from torch.nn.functional import interpolate

from pathlib import Path

from torch.utils.data import ConcatDataset, DataLoader, RandomSampler

from torchvision.datasets import MNIST
from torchvision.transforms import v2
from torchvision.transforms.functional import pil_to_tensor, to_pil_image
from torchvision.utils import make_grid

from diffusers import DDPMScheduler, DDPMPipeline, DDIMPipeline, UNet2DModel
from diffusers.optimization import get_cosine_schedule_with_warmup
from diffusers import DDIMScheduler

from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity

PATH = ""

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import seaborn as sns
sns.set(palette='Set2')

from IPython.display import HTML
from IPython.display import clear_output

seed = 42
import random
random.seed(seed)
torch.manual_seed(seed);

import torch
torch.set_num_threads(20)

# %%
import seaborn as sns
sns.set(palette='Set2', font_scale=1.3)

device = torch.device("cuda:7" if torch.cuda.is_available() else "cpu")
USE_CUDA = torch.cuda.is_available()

# %% [markdown]
# ---
# ### Задача 4.
#
# Продолжим сравнение диффузии, начатое в задаче 1 домашнего задания 3 по генеративным моделям. Для сравнения моделей используйте
# * визуальное сравнение качества сгенерированных объектов,
# * стабильность обучения модели,
# * метрику FID.

# %% [markdown]
# **1.** Для построения диффузионной модели мы обучаем нейросеть предсказывать $\delta_\theta(x_t, t)$ &mdash; кумулятивный шум, с помощью которого получен текущий $X_t$ из исходного $X_0$. Такой процесс соответствует репараметризации совместного распределения данных, и теоретически эквивалентен исходной параметризации, в которой обучается нейросеть $x_\theta(x_t, t)$, которая предсказывает исходный $X_0$ по текущему значению $X_t$.
#
# Сравните эти два случая.

# %% [markdown]
# Для начала выпишем код с дз 3, который нам пригодится

# %%
def normalize(image):
    """
    Нормализация для изображений из MNIST
    """
    return (image * 2 - 1).to(torch.float32)

def unnormalize(image):
    return ((image.clamp(-1, 1) + 1) / 2 * 255).to(torch.uint8)

transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Lambda(normalize),
])

mnist_train = MNIST(root='.', train=True, transform=transform, download=True)
mnist_test = MNIST(root='.', train=False, transform=transform, download=True)
mnist = ConcatDataset([mnist_train, mnist_test])

def noise_images(images, steps, alpha_hat,device="cpu"):
    sqrt_alpha_hat = torch.sqrt(alpha_hat[steps])[:, None, None, None].to(device)
    sqrt_one_minus_alpha_hat = torch.sqrt(1 - alpha_hat[steps])[:, None, None, None].to(device)
    noise = torch.randn_like(images)
    return sqrt_alpha_hat * images + sqrt_one_minus_alpha_hat * noise, noise

def sample_images_one_step(
    noised_images,
    predicted_noise,
    steps,
    beta,
    alpha,
    alpha_hat,
    total_num_steps,
    add_noise=False,
):
    beta_step = beta[steps][:, None, None, None]
    if add_noise:
        noise = torch.randn_like(noised_images)
    else:
        noise = torch.zeros_like(noised_images)
    alpha_step = alpha[steps][:, None, None, None].to(device)
    alpha_hat_step = alpha_hat[steps][:, None, None, None].to(device)
    beta_step = beta[steps][:, None, None, None].to(device)
    return (
        1
        / torch.sqrt(alpha_step)
        * (
            noised_images
            - (1 - alpha_step) / (torch.sqrt(1 - alpha_hat_step)) * predicted_noise
        )
        + torch.sqrt(beta_step) * noise
    )


def sample_images(
    model,
    num_images,
    beta,
    alpha,
    alpha_hat,
    img_size=28,
    start_step=1000,
    finish_step=1,
    noised_images=None,
    device="cpu",
    return_full_trace=False,
):
    if noised_images is None:
        noised_images = torch.randn((num_images, 1, img_size, img_size)).to(device)

    full_traced = []
    for i in tqdm(
        reversed(range(finish_step, start_step)),
        position=0,
        total=start_step - finish_step,
    ):
        steps = (torch.ones(num_images) * i).long()
        with torch.no_grad():
            predicted_noise = model(noised_images, steps.to(device)).sample
        add_noise = True if i > 1 else False
        noised_images = sample_images_one_step(
            noised_images,
            predicted_noise,
            steps,
            beta,
            alpha,
            alpha_hat,
            start_step,
            add_noise=add_noise,
        )
        if return_full_trace:
            full_traced.append(noised_images.clone().detach().cpu())
    if return_full_trace:
        return noised_images, full_traced
    return noised_images

@torch.no_grad()
def visualize_training_progress(
    model,
    noise_scheduler,
    losses,
    total_num_steps: int,
    device="cpu",
    num_images: int = 9,
    nrow: int = 3,
):
    model.eval()

    # === график лоссов ===
    fig, (ax_loss, ax_imgs) = plt.subplots(1, 2, figsize=(14, 6))
    ax_loss.plot(np.arange(len(losses)) * 10, losses, color="teal")
    ax_loss.set_title("Loss history")
    ax_loss.set_xlabel("Iteration")
    ax_loss.set_ylabel("MSE loss")

    # === генерация изображений ===
    shape = (1, 28, 28)
    noisy = torch.randn((num_images, *shape), device=device)

    num_vis_steps = total_num_steps
    for t in reversed(range(num_vis_steps)):
        steps = torch.ones(num_images, device=device, dtype=torch.long) * t
        pred_noise = model(noisy, steps).sample
        noisy = noise_scheduler.step(pred_noise, t, noisy).prev_sample

    imgs = (noisy.clamp(-1, 1) + 1) / 2
    grid = make_grid(imgs, nrow=nrow)

    ax_imgs.imshow(grid.permute(1, 2, 0).cpu().numpy())
    ax_imgs.axis("off")
    ax_imgs.set_title("Generated samples")

    clear_output(wait=True)
    display(fig)
    plt.close(fig)

# %%
def normalize_images(x):
    """Надёжная нормализация к [0, 1]"""
    if x.min() >= 0 and x.max() <= 1:
        return x.clamp(0, 1)
    elif x.min() >= -1 and x.max() <= 1:
        return ((x + 1) / 2).clamp(0, 1)
    elif x.max() > 1:
        return (x / 255.0).clamp(0, 1)
    return x.clamp(0, 1)


@torch.no_grad()
def compute_fid_score(real_images, fake_images, device="cpu", batch_size=64):
    """Вычисление FID между real_images и fake_images"""
    real_images = normalize_images(real_images).float()
    fake_images = normalize_images(fake_images).float()

    # повторяем каналы, если изображение одноканальное
    if real_images.size(1) == 1:
        real_images = real_images.repeat_interleave(3, dim=1)
        fake_images = fake_images.repeat_interleave(3, dim=1)

    fid_metric = FrechetInceptionDistance(feature=2048, normalize=True).to(device)

    for start in range(0, real_images.size(0), batch_size):
        r = real_images[start:start + batch_size]
        f = fake_images[start:start + batch_size]

        r = F.interpolate(r, size=(299, 299), mode="bilinear", align_corners=False)
        f = F.interpolate(f, size=(299, 299), mode="bilinear", align_corners=False)

        fid_metric.update(r.to(device), real=True)
        fid_metric.update(f.to(device), real=False)

    return fid_metric.compute().item()


@torch.no_grad()
def evaluate_fid(
    model, dataloader, betas_dict, device="cuda", num_images_to_sample=5000
):
    """Упрощённая версия: одна модель, один FID"""
    beta, alpha, alpha_hat = betas_dict

    # собираем изображения из даталоадера
    collected_real = []
    for real_imgs, _ in dataloader:
        collected_real.append(real_imgs)
        if len(collected_real) * real_imgs.shape[0] >= num_images_to_sample:
            break

    real_cat = torch.cat(collected_real, dim=0)[:num_images_to_sample].to(device)
    print(f"Диапазон реальных изображений: [{real_cat.min():.3f}, {real_cat.max():.3f}]")

    # сэмплируем из диффузии
    print(f"Сэмплирование {num_images_to_sample} изображений ...")
    fake_imgs = sample_images(
        model=model,
        num_images=num_images_to_sample,
        beta=beta,
        alpha=alpha,
        alpha_hat=alpha_hat,
        img_size=28,
        start_step=len(beta),
        finish_step=1,
        device=device,
    ).cpu()

    print(f"Диапазон сэмплированных изображений: [{fake_imgs.min():.3f}, {fake_imgs.max():.3f}]")

    # считаем FID
    fid_value = compute_fid_score(real_cat.cpu(), fake_imgs, device=device)
    print(f"FID = {fid_value:.2f}")

    return fid_value

# %%
batch_size = 64
dataloader = DataLoader(
    mnist,
    batch_size=batch_size,
    sampler=RandomSampler(
        mnist,
        replacement=True
    )
)

# %%
def init_training_modules(
    lr_warmup_steps, num_epochs, train_num_steps, beta_start, beta_end, device="cpu"
):
    """
    Инициализация различных модулей для обучения модели.
    """
    # Модель для восстановления шума
    model = UNet2DModel(
        sample_size=28,  # разрешение выходного изображения
        in_channels=1,  # количестов входных каналов
        out_channels=1,  # количество выходных каналов
        layers_per_block=2,  # количество ResNet слоев, используемых в каждом UNet блоке
        block_out_channels=(
            64,
            128,
            256,
        ),  # количество выходных каналов для UNet блоков
        down_block_types=(
            "DownBlock2D",  # стандартный ResNet downsampling блок
            "DownBlock2D",
            "DownBlock2D",
        ),
        up_block_types=(
            "UpBlock2D",  # стандартный ResNet upsampling блок
            "UpBlock2D",
            "UpBlock2D",
        ),
    )
    model.to(device)
    model.train()

    # Модуль контроля над уровнем шума -- взялли из Diffusers.
    # В данном случае он такой же, как в примере выше.
    noise_scheduler = DDPMScheduler(
        num_train_timesteps=train_num_steps, beta_start=beta_start, beta_end=beta_end
    )

    # Оптимизатор
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3)

    # Планировщик для скорости обучения (можно было обойтись без него)
    lr_scheduler = get_cosine_schedule_with_warmup(
        optimizer=optimizer,
        num_warmup_steps=lr_warmup_steps,
        num_training_steps=(len(dataloader) * num_epochs),
    )

    # Функция ошибки
    criterion = nn.MSELoss()

    output = (model, noise_scheduler, optimizer, lr_scheduler, criterion)

    return output

# %% [markdown]
# Обучение через кумулятивный шум у нас уже было реализована в дз 3.

# %%
def train_model_via_noise(
    model,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    num_epochs,
    total_num_steps,
    device="cpu",
    writer=None,
    plot_interval=200,
):
    losses = []
    global_iter = 0

    for epoch in range(num_epochs):
        for i, (images, _) in enumerate(tqdm(dataloader, "Training")):
            model.train()
            images = images.to(device)

            steps = torch.randint(0, total_num_steps, (images.size(0),), device=device)
            noise = torch.randn_like(images)
            noised_images = noise_scheduler.add_noise(images, noise, steps)
            predicted_noise = model(noised_images, steps).sample
            loss = criterion(noise, predicted_noise)

            if global_iter % 10 == 0:
                losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            global_iter += 1

            if (global_iter % plot_interval == 0) or (i == len(dataloader) - 1):
                visualize_training_progress(
                    model, noise_scheduler, losses, total_num_steps, device,
                )

    return losses

# %% [markdown]
# Теперь реализуем случай, когда мы предсказываем все изображение

# %%
def train_model_via_image(
    model,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    num_epochs,
    total_num_steps,
    device="cpu",
    writer=None,
    plot_interval=200,
):
    losses = []
    global_iter = 0

    for epoch in range(num_epochs):
        for i, (images, _) in enumerate(tqdm(dataloader, "Training")):
            model.train()
            images = images.to(device)

            steps = torch.randint(0, total_num_steps, (images.size(0),), device=device)
            noise = torch.randn_like(images)
            noised_images = noise_scheduler.add_noise(images, noise, steps)
            original_image_pred = model(noised_images, steps).sample
            loss = criterion(images, original_image_pred)

            if global_iter % 10 == 0:
                losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            global_iter += 1

            if (global_iter % plot_interval == 0) or (i == len(dataloader) - 1):
                visualize_training_progress(
                    model, noise_scheduler, losses, total_num_steps, device,
                )

    return losses

# %%
NUM_EPOCHS = 7

# %%
lr_warmup_steps = 100 # количество итераций на разогрев скедулера
num_epochs = NUM_EPOCHS # количество эпох
plot_interval = 99999 # периодичность вывода графиков
train_num_steps=1000

# %%
losses_dict = {}
models = {}
betas_dict = {}
beta_start, beta_end = 1e-4, 2e-2
beta = torch.linspace(beta_start, beta_end, train_num_steps)
alpha = 1.0 - beta
alpha_hat = torch.cumprod(alpha, dim=0)

model_via_noise, noise_scheduler, optimizer, lr_scheduler, criterion = init_training_modules(
    lr_warmup_steps, num_epochs, train_num_steps, beta_start, beta_end, device
)
betas_dict[train_num_steps] = (beta, alpha, alpha_hat)

losses = train_model_via_noise(
    model_via_noise,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    total_num_steps=train_num_steps,
    num_epochs=num_epochs,
    device=device,
    plot_interval=plot_interval,
)

# %%
model_via_image, noise_scheduler, optimizer, lr_scheduler, criterion = init_training_modules(
    lr_warmup_steps, num_epochs, train_num_steps, beta_start, beta_end, device
)

losses = train_model_via_noise(
    model_via_image,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    total_num_steps=train_num_steps,
    num_epochs=num_epochs,
    device=device,
    plot_interval=plot_interval,
)

# %% [markdown]
# Изображения сгенерированные моделью с репараметризацией

# %%
noised_images = sample_images(
        model_via_noise, 10, beta, alpha, alpha_hat, start_step=train_num_steps, device=device
    )
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]

# %%
grid = make_grid(
    [unnormalize(img) for img in noised_images],  # вернуть диапазон [0,255]
    nrow=len(noised_images),
)
img_pil = to_pil_image(grid)

# Отрисовка без подписей, осей и лишних графиков
plt.figure(figsize=(18, 4))
plt.imshow(img_pil)
plt.axis("off")
plt.title(f"{train_num_steps} diffusion steps", fontsize=14)
plt.show()

# %% [markdown]
# Изображения сгенерированные моделью без репараметризации

# %%
noised_images = sample_images(
        model_via_image, 10, beta, alpha, alpha_hat, start_step=train_num_steps, device=device
    )
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]

# %%
grid = make_grid(
    [unnormalize(img) for img in noised_images],  # вернуть диапазон [0,255]
    nrow=len(noised_images),
)
img_pil = to_pil_image(grid)

# Отрисовка без подписей, осей и лишних графиков
plt.figure(figsize=(18, 4))
plt.imshow(img_pil)
plt.axis("off")
plt.title(f"{train_num_steps} diffusion steps", fontsize=14)
plt.show()

# %% [markdown]
# Сравним модели

# %%
fid_value = evaluate_fid(model_via_noise, dataloader, (beta, alpha, alpha_hat), device=device, num_images_to_sample=5000)
print("FID модели обученной через репараметризацию:", fid_value)
# Out:
# Диапазон реальных изображений: [-1.000, 1.000]
# Сэмплирование 5000 изображений ...
#   0%|          | 0/999 [00:00<?, ?it/s]
# Диапазон сэмплированных изображений: [-1.090, 1.079]
# FID = 451.87
# FID модели обученной через репараметризацию: 451.8739318847656

# %%
fid_value = evaluate_fid(model_via_image, dataloader, (beta, alpha, alpha_hat), device=device, num_images_to_sample=5000)
print("FID модели обученной без репараметризации:", fid_value)
# Out:
# Диапазон реальных изображений: [-1.000, 1.000]
# Сэмплирование 5000 изображений ...
#   0%|          | 0/999 [00:00<?, ?it/s]
# Диапазон сэмплированных изображений: [-1.126, 1.091]
# FID = 451.81
# FID модели обученной без репараметризации: 451.8121337890625

# %% [markdown]
# Качество по FID у моделей сопоставим, обучаются они тоже одинаково стабильно.
#
# Модель предсказывающая шум выдает чуть больше артефактов в изображении

# %% [markdown]
# **2.** В формуле для ELBO мы получили среднюю квадратичную ошибку, домноженную на некоторый коэффициент, зависящий от $t$. На практике часто при обучении модели этот коэффициент отбрасывается.
#
# Исследуйте, как меняется этот коэффициент в зависимости от $t$.

# %% [markdown]
# Помним, ELBO имеет следующий вид для репараметризованного:
#
# \begin{align*}
# ELBO = const - \sum_{t=2}^T \frac{\beta_t^2}{2\alpha_t \tilde{\beta}_t(1 - \tilde{\alpha}_t)}E_{q}||\delta_t - \delta_{\theta}(x_t, t)||^2.
# \end{align*}
#
# То же выражение без репараметризации:
#
# \begin{align*}
# ELBO = const - \sum_{t=2}^T \frac{\tilde{\alpha}_{t-1}\beta_t}{2\tilde{\beta}_t(1 - \tilde{\alpha}_t)^2}E_{q}||X_0 - X_{\theta}(X_t, t)||^2.
# \end{align*}

# %%
def calculate_factor_in_ELBO_noise(betas_dict, train_num_steps=1000):
    beta, alpha, alpha_hat = betas_dict[train_num_steps]

    beta = beta.detach().cpu().numpy()
    alpha = alpha.detach().cpu().numpy()
    alpha_hat = alpha_hat.detach().cpu().numpy()

    T = len(beta)
    beta_hat = (1 - alpha_hat[1:T - 1]) / (1 - alpha_hat[2:T]) * beta[2:]

    w_t = np.ones(T)
    w_t[2:T] = beta[2:] ** 2 / (2 * alpha[2:] * beta_hat * (1 - alpha_hat[2:]))
    return w_t

def calculate_factor_in_ELBO_image(betas_dict, train_num_steps=1000):
    beta, alpha, alpha_hat = betas_dict[train_num_steps]

    beta = beta.detach().cpu().numpy()
    alpha = alpha.detach().cpu().numpy()
    alpha_hat = alpha_hat.detach().cpu().numpy()

    T = len(beta)
    beta_hat = (1 - alpha_hat[1:T - 1]) / (1 - alpha_hat[2:T]) * beta[2:]

    w_t = np.ones(T)
    w_t[2:T] = alpha_hat[1:T-1] * beta[2:] / (2 * beta_hat * (1 - alpha_hat[2:])**2)
    return w_t

# %% [markdown]
# Для репараметризации

# %%
w_t_noise = calculate_factor_in_ELBO_noise(betas_dict)
t_s = np.arange(len(w_t_noise))


plt.figure(figsize=(8,5))
plt.plot(t_s, w_t_noise, marker='o', linestyle='-')
plt.xlabel("Шаг времени t")
plt.ylabel(r"$\log w_t = \log \frac{\beta_t^2}{2 \alpha_t \tilde{\beta}_t (1-\tilde{\alpha}_t)}$")
plt.title("Зависимость коэффициента w_t в ELBO от времени t")
plt.grid(True)
plt.yscale("log")
plt.show()

# %% [markdown]
# Без репараметризации

# %%
w_t_image = calculate_factor_in_ELBO_image(betas_dict)
t_s = np.arange(len(w_t_image))

plt.figure(figsize=(8,5))
plt.plot(t_s, w_t_image, marker='o', linestyle='-')
plt.xlabel("Шаг времени t")
plt.ylabel(r"$\log w_t = \log \frac{\tilde{\alpha}_{t-1}\beta_t}{2\tilde{\beta}_t(1 - \tilde{\alpha}_t)^2}$")
plt.title("Зависимость коэффициента w_t в ELBO от времени t")
plt.grid(True)
plt.yscale("log")
plt.show()

# %% [markdown]
# Сравните модели, обученные с использованием коэффициента и без него.

# %% [markdown]
# До этого мы обучали модель без этого коэффициента, добавим его, и снова проведем те же опыты.

# %%
def train_model_via_noise_with_coeff(
    model,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    num_epochs,
    total_num_steps,
    w_t,
    device="cpu",
    writer=None,
    plot_interval=200,
):
    losses = []
    global_iter = 0
    w_t = torch.as_tensor(w_t, dtype=torch.float32, device=device)

    for epoch in range(num_epochs):
        for i, (images, _) in enumerate(tqdm(dataloader, "Training")):
            model.train()
            images = images.to(device)

            steps = torch.randint(0, total_num_steps, (images.size(0),), device=device)
            noise = torch.randn_like(images)
            noised_images = noise_scheduler.add_noise(images, noise, steps)
            predicted_noise = model(noised_images, steps).sample
            
            loss_per_pixel = torch.square(noise - predicted_noise)  # [B, C, H, W]
            loss_per_sample = loss_per_pixel.mean(dim=(1, 2, 3))     # [B]
            weights = w_t[steps]                                     # [B]
            loss = (weights * loss_per_sample).mean()

            if global_iter % 10 == 0:
                losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            global_iter += 1

            if (global_iter % plot_interval == 0) or (i == len(dataloader) - 1):
                visualize_training_progress(
                    model, noise_scheduler, losses, total_num_steps, device,
                )

    return losses

# %%
model_via_noise_with_coeff, noise_scheduler, optimizer, lr_scheduler, criterion = init_training_modules(
    lr_warmup_steps, num_epochs, train_num_steps, beta_start, beta_end, device
)

losses = train_model_via_noise_with_coeff(
    model_via_noise_with_coeff,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    total_num_steps=train_num_steps,
    w_t=w_t_noise,
    num_epochs=num_epochs,
    device=device,
    plot_interval=plot_interval,
)

# %%
def train_model_via_image_with_coeff(
    model,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    num_epochs,
    total_num_steps,
    w_t,
    device="cpu",
    writer=None,
    plot_interval=200,
):
    losses = []
    global_iter = 0
    w_t = torch.as_tensor(w_t, dtype=torch.float32, device=device)

    for epoch in range(num_epochs):
        for i, (images, _) in enumerate(tqdm(dataloader, "Training")):
            model.train()
            images = images.to(device)

            steps = torch.randint(0, total_num_steps, (images.size(0),), device=device)
            noise = torch.randn_like(images)
            noised_images = noise_scheduler.add_noise(images, noise, steps)
            original_image_pred = model(noised_images, steps).sample
            loss = criterion(images, original_image_pred)

            loss_per_pixel = torch.square(images - original_image_pred)  # [B, C, H, W]
            loss_per_sample = loss_per_pixel.mean(dim=(1, 2, 3))     # [B]
            weights = w_t[steps]                                     # [B]
            loss = (weights * loss_per_sample).mean()

            if global_iter % 10 == 0:
                losses.append(loss.item())

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_scheduler.step()
            global_iter += 1

            if (global_iter % plot_interval == 0) or (i == len(dataloader) - 1):
                visualize_training_progress(
                    model, noise_scheduler, losses, total_num_steps, device,
                )

    return losses

# %%
model_via_image_with_coeff, noise_scheduler, optimizer, lr_scheduler, criterion = init_training_modules(
    lr_warmup_steps, num_epochs, train_num_steps, beta_start, beta_end, device
)

losses = train_model_via_image_with_coeff(
    model_via_noise_with_coeff,
    dataloader,
    noise_scheduler,
    optimizer,
    lr_scheduler,
    criterion,
    total_num_steps=train_num_steps,
    w_t=w_t_image,
    num_epochs=num_epochs,
    device=device,
    plot_interval=plot_interval,
)

# %% [markdown]
# В обоих случаях обучение полностью развалилось. Вероятно это связано со слишком сильном дисбалансом весов, когда одно сначала коэффициенты большие, а потом уменьшаются на порядка, из-за чего обучение происходит неравномерно.

# %% [markdown]
# Также исследуйте, как меняется квадратичная ошибка обученной модели в зависимости от $t$ при использовании коэффициента во время обучения и без его использования.

# %%
def evaluate_mse_per_t(
    model,
    dataloader,
    noise_scheduler,
    device,
    T,
    predict_noise=True,
    plot_title="MSE по шагам времени t",
):
    model.eval()
    mse_per_t = torch.zeros(T, device=device)
    count_per_t = torch.zeros(T, device=device)

    with torch.no_grad():
        for (x0_batch, _) in tqdm(dataloader):
            x0_batch = x0_batch.to(device)
            batch_size = x0_batch.shape[0]
            t = torch.randint(0, T, (batch_size,), device=device)

            eps = torch.randn_like(x0_batch)
            alpha_bar_t = noise_scheduler.alphas_cumprod[t].view(-1, 1, 1, 1)
            xt = torch.sqrt(alpha_bar_t) * x0_batch + torch.sqrt(1 - alpha_bar_t) * eps

            pred = model(xt, t).sample

            if predict_noise:
                mse = (eps - pred).pow(2).mean(dim=[1, 2, 3])  # [B]
            else:
                mse = (x0_batch - pred).pow(2).mean(dim=[1, 2, 3])  # [B]

            for i in range(batch_size):
                ti = t[i].item() - 1
                mse_per_t[ti] += mse[i]
                count_per_t[ti] += 1

    mse_per_t = mse_per_t / (count_per_t + 1e-8)
    mse_per_t_np = mse_per_t.cpu().numpy()

    t_vals = np.arange(1, T + 1)

    plt.figure(figsize=(10, 6))
    plt.plot(
        t_vals,
        mse_per_t_np,
        marker="o",
        linestyle="-",
        linewidth=2,
        markersize=4,
        label="MSE(t)",
    )
    plt.xlabel("Шаг времени t")
    plt.ylabel("MSE(t)")
    plt.title(plot_title)
    plt.grid(True, alpha=0.3)
    plt.xticks(np.arange(0, T + 1, max(1, T // 10)))
    plt.tight_layout()

    plt.show()

    return mse_per_t_np

# %%
mse_with_w_noise = evaluate_mse_per_t(
    model_via_noise,
    dataloader,
    noise_scheduler,
    device,
    T=train_num_steps,
    predict_noise=True,
    plot_title="MSE(t) — модель предсказывает шум, обучена без коэффициента"
)
# Out:
#   0%|          | 0/1094 [00:00<?, ?it/s]

# %%
mse_with_w_noise = evaluate_mse_per_t(
    model_via_noise_with_coeff,
    dataloader,
    noise_scheduler,
    device,
    T=train_num_steps,
    predict_noise=True,
    plot_title="MSE(t) — модель предсказывает шум, обучена с коэффициентом"
)
# Out:
#   0%|          | 0/1094 [00:00<?, ?it/s]

# %%
mse_with_w_noise = evaluate_mse_per_t(
    model_via_image,
    dataloader,
    noise_scheduler,
    device,
    T=train_num_steps,
    predict_noise=True,
    plot_title="MSE(t) — модель предсказывает изображение, обучена без коэффициента"
)
# Out:
#   0%|          | 0/1094 [00:00<?, ?it/s]

# %%
mse_with_w_noise = evaluate_mse_per_t(
    model_via_image_with_coeff,
    dataloader,
    noise_scheduler,
    device,
    T=train_num_steps,
    predict_noise=True,
    plot_title="MSE(t) — модель предсказывает шум, обучена с коэффициентом"
)
# Out:
#   0%|          | 0/1094 [00:00<?, ?it/s]

# %% [markdown]
# Как видим, обучение с коэффициентом более хаотичное, что прекрасно видно по изображениям, которые генерирует модель.

# %% [markdown]
# **3.** Сделайте выводы.

# %% [markdown]
# **Выводы**
#
# Как видим, нет большой разницы, как минимум в случае изображений малой размерности, между тем чтобы предсказывать шум, или саму картинку. Качество, как визуально, так и по метрикам сопоставимо.
#
#
# Коэффициент, который у нас получился в ELBO следует принять равным 1, иначе в лосс становится диспропорциональным, и обучение ломается.

# %% [markdown]
# ---
# © 2025 команда <a href="https://thetahat.ru/">ThetaHat</a> для DS-потока
